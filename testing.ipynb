# %%
import pandas as pd

# %%
ccle_annotations = pd.read_csv("cancer_data/data/raw/Cell_lines_annotations_20181226.txt",sep="\t")

# %%
ccle_annotations
# Out:
#                                        CCLE_ID    depMapID       Name  \
# 0                                   DMS53_LUNG  ACH-000698     DMS 53
# 1                       SW1116_LARGE_INTESTINE  ACH-000489     SW1116
# 2                                NCIH1694_LUNG  ACH-000431  NCI-H1694
# 3     P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  ACH-000707     P3HR-1
# 4     HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE  ACH-000509     HuT 78
# ...                                        ...         ...        ...
# 1456                       GEO_LARGE_INTESTINE  ACH-002394        NaN
# 1457                             NCIH2330_LUNG         NaN        NaN
# 1458                           LP6_SOFT_TISSUE  ACH-001116        NaN
# 1459                           HS578BST_BREAST         NaN        NaN
# 1460                                LC1SQ_LUNG  ACH-002156        NaN
#
#        Pathology                        Site_Primary Site_Subtype1  \
# ...

# %%
ccle_to_depmap = dict(zip(ccle_annotations["CCLE_ID"],ccle_annotations["depMapID"]))

# %%
rppa_info = pd.read_csv("cancer_data/data/raw/CCLE_RPPA_Ab_info_20181226.csv")

# %%
rppa_info["format_id"]
# Out:
#               Antibody_Name Target_Genes Validation_Status            Company  \
# 0               14-3-3_beta        YWHAB         Validated         Santa Cruz
# 1    14-3-3_epsilon_Caution        YWHAE           Caution         Santa Cruz
# 2               14-3-3_zeta        YWHAZ         Validated         Santa Cruz
# 3                    4E-BP1     EIF4EBP1         Validated                CST
# 4               4E-BP1_pS65     EIF4EBP1         Validated                CST
# ..                      ...          ...               ...                ...
# 209           XRCC1_Caution        XRCC1           Caution                CST
# 210             YAP_Caution         YAP1           Caution         Santa Cruz
# 211       YAP_pS127_Caution         YAP1           Caution                CST
# 212                    YB-1         YBX1         Validated  Novus Biologicals
# 213              YB-1_pS102         YBX1         Validated                CST
#
#     Catalog_Number
# ...

# %%
df = pd.read_csv("cancer_data/data/raw/CCLE_RPPA_20181003.csv",index_col=0)

# %%
df
# Out:
#                                           14-3-3_beta  14-3-3_epsilon_Caution  \
# DMS53_LUNG                                  -0.104888                0.060414
# SW1116_LARGE_INTESTINE                       0.358504               -0.180291
# NCIH1694_LUNG                                0.028738                0.071902
# P3HR1_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE     0.120039               -0.066802
# HUT78_HAEMATOPOIETIC_AND_LYMPHOID_TISSUE    -0.268997               -0.060281
# ...                                               ...                     ...
# UO31_KIDNEY                                  0.043231                0.093158
# SF268_CENTRAL_NERVOUS_SYSTEM                -0.034597                0.065964
# SF539_CENTRAL_NERVOUS_SYSTEM                -0.250998                0.420490
# SNB75_CENTRAL_NERVOUS_SYSTEM                -0.139833                0.194831
# HOP92_LUNG                                   0.057413               -0.069547
#
# ...

# %%
df.index.map(ccle_to_depmap.get)
# Out:
# Index(['ACH-000698', 'ACH-000489', 'ACH-000431', 'ACH-000707', 'ACH-000509',
#        'ACH-000522', 'ACH-000613', 'ACH-000829', 'ACH-000557', 'ACH-000614',
#        ...
#        'ACH-000590', 'ACH-000964', 'ACH-000861', 'ACH-000706', 'ACH-001151',
#        'ACH-000428', 'ACH-000655', 'ACH-000273', 'ACH-000504', 'ACH-000825'],
#       dtype='object', length=899)
